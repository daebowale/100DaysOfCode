# %%
import pandas as pd

# %%
readCsv = pd.read_csv("nifty50_DataAnalysis.csv")

# %%
readCsv
# Out:
#             Date      Symbol Series  Prev Close    Open     High     Low  \
# 0     27-11-2007  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1     28-11-2007  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2     29-11-2007  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3     30-11-2007  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4     03-12-2007  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...          ...         ...    ...         ...     ...      ...     ...
# 3317  26-04-2021  ADANIPORTS     EQ      725.35  733.00   739.65  728.90
# 3318  27-04-2021  ADANIPORTS     EQ      730.75  735.00   757.50  727.35
# 3319  28-04-2021  ADANIPORTS     EQ      749.15  755.00   760.00  741.10
# 3320  29-04-2021  ADANIPORTS     EQ      746.25  753.20   765.85  743.40
# 3321  30-04-2021  ADANIPORTS     EQ      746.75  739.00   759.45  724.50
#
#        Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
readCsv.head(10) # Take first 10 data
# Out:
#          Date      Symbol Series  Prev Close     Open     High     Low  \
# 0  27-11-2007  MUNDRAPORT     EQ      440.00   770.00  1050.00   770.0
# 1  28-11-2007  MUNDRAPORT     EQ      962.90   984.00   990.00   874.0
# 2  29-11-2007  MUNDRAPORT     EQ      893.90   909.00   914.75   841.0
# 3  30-11-2007  MUNDRAPORT     EQ      884.20   890.00   958.00   890.0
# 4  03-12-2007  MUNDRAPORT     EQ      921.55   939.75   995.00   922.0
# 5  04-12-2007  MUNDRAPORT     EQ      969.30   985.00  1056.00   976.0
# 6  05-12-2007  MUNDRAPORT     EQ     1041.45  1061.00  1099.50  1050.0
# 7  06-12-2007  MUNDRAPORT     EQ     1082.45  1089.00  1109.70  1051.0
# 8  07-12-2007  MUNDRAPORT     EQ     1081.30  1100.00  1134.00  1078.0
# 9  10-12-2007  MUNDRAPORT     EQ     1102.40  1110.00  1110.00  1061.1
#
#       Last    Close     VWAP    Volume      Turnover  Trades  \
# 0   959.00   962.90   984.72  27294366  2.690000e+15     NaN
# 1   885.00   893.90   941.38   4581338  4.310000e+14     NaN
# ...

# %%
readCsv.tail(10) # Take last 10 data
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 3312  16-04-2021  ADANIPORTS     EQ      750.35  750.90  794.85  743.00
# 3313  19-04-2021  ADANIPORTS     EQ      755.50  715.00  730.90  707.45
# 3314  20-04-2021  ADANIPORTS     EQ      720.95  744.70  745.90  710.00
# 3315  22-04-2021  ADANIPORTS     EQ      720.45  689.50  744.90  689.50
# 3316  23-04-2021  ADANIPORTS     EQ      737.80  736.45  746.90  720.10
# 3317  26-04-2021  ADANIPORTS     EQ      725.35  733.00  739.65  728.90
# 3318  27-04-2021  ADANIPORTS     EQ      730.75  735.00  757.50  727.35
# 3319  28-04-2021  ADANIPORTS     EQ      749.15  755.00  760.00  741.10
# 3320  29-04-2021  ADANIPORTS     EQ      746.25  753.20  765.85  743.40
# 3321  30-04-2021  ADANIPORTS     EQ      746.75  739.00  759.45  724.50
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# 3312  749.15  755.50  770.01  41791181  3.220000e+15  499686.0
# ...

# %%
readCsv["Symbol"]
# Out:
# 0       MUNDRAPORT
# 1       MUNDRAPORT
# 2       MUNDRAPORT
# 3       MUNDRAPORT
# 4       MUNDRAPORT
#            ...
# 3317    ADANIPORTS
# 3318    ADANIPORTS
# 3319    ADANIPORTS
# 3320    ADANIPORTS
# 3321    ADANIPORTS
# Name: Symbol, Length: 3322, dtype: object

# %%
readCsv["Turnover"]
# Out:
# 0       2.690000e+15
# 1       4.310000e+14
# 2       4.550000e+14
# 3       4.280000e+14
# 4       2.880000e+14
#             ...
# 3317    6.890000e+14
# 3318    1.540000e+15
# 3319    8.380000e+14
# 3320    1.040000e+15
# 3321    9.370000e+14
# Name: Turnover, Length: 3322, dtype: float64

# %%
print(readCsv["Series"].dtype)
# Out:
# object

# %%
print(readCsv["Trades"].astype("category")) # Change the data type
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 3317    116457.0
# 3318    236896.0
# 3319    130847.0
# 3320    153293.0
# 3321    132141.0
# Name: Trades, Length: 3322, dtype: category
# Categories (2417, float64): [366.0, 417.0, 427.0, 897.0, ..., 499686.0, 655274.0, 747062.0, 1205984.0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_2260\2701531066.py:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   print(readCsv["Trades"].astype("category"))

# %%
# Returns reshaped DataFrame.
pdpivot = readCsv.pivot(index="Date",columns=["Symbol", "Series"],values="Volume")
print(pdpivot)
# Out:
# Symbol     MUNDRAPORT ADANIPORTS
# Series             EQ         EQ
# Date
# 01-01-2008   491348.0        NaN
# 01-01-2009   136138.0        NaN
# 01-01-2013        NaN   353823.0
# 01-01-2014        NaN   851727.0
# 01-01-2015        NaN  1456204.0
# ...               ...        ...
# 31-12-2014        NaN  3559436.0
# 31-12-2015        NaN  2727837.0
# 31-12-2018        NaN  2062181.0
# 31-12-2019        NaN  2043206.0
# 31-12-2020        NaN  4386328.0
#
# [3322 rows x 2 columns]

# %%
print(readCsv["Turnover"])
# Out:
# 0       2.690000e+15
# 1       4.310000e+14
# 2       4.550000e+14
# 3       4.280000e+14
# 4       2.880000e+14
#             ...
# 3317    6.890000e+14
# 3318    1.540000e+15
# 3319    8.380000e+14
# 3320    1.040000e+15
# 3321    9.370000e+14
# Name: Turnover, Length: 3322, dtype: float64

# %%
# pd.eval() is used to do some mathematical operations with data like that, 
print(pd.eval("Double_Turnover = readCsv.Turnover * 2", target=readCsv))
# Out:
#             Date      Symbol Series  Prev Close    Open     High     Low  \
# 0     27-11-2007  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1     28-11-2007  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2     29-11-2007  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3     30-11-2007  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4     03-12-2007  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...          ...         ...    ...         ...     ...      ...     ...
# 3317  26-04-2021  ADANIPORTS     EQ      725.35  733.00   739.65  728.90
# 3318  27-04-2021  ADANIPORTS     EQ      730.75  735.00   757.50  727.35
# 3319  28-04-2021  ADANIPORTS     EQ      749.15  755.00   760.00  741.10
# 3320  29-04-2021  ADANIPORTS     EQ      746.25  753.20   765.85  743.40
# 3321  30-04-2021  ADANIPORTS     EQ      746.75  739.00   759.45  724.50
#
#        Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
# %matplotlib inline  

from matplotlib import pyplot as plt

# %%
# Visualixing data and plot graph btw date and turnover
plt.plot(readCsv["Date"], readCsv["Turnover"])
plt.title("Graph on Date vs Turnover")
plt.xlabel("Date")
plt.ylabel("Total Turnover")
plt.show()

# %% [markdown]
# Thank you ;)
